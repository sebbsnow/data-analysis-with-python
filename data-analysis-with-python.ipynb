# %% [markdown]
# # DATA ANALYSIS WITH PYTHON

# %% [markdown]
# ## ========= PART 1 =========

# %% [markdown]
# ## IMPORTER LES LIBRAIRIES

# %%
# Importer les librairies Pandas et Numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ## IMPORTER LES DONNÉES

# %%
# Importer les données
# reviews = pd.read_csv("dataset/ign.csv", index_col=0, encoding="latin-1")
# index_col=0, veut dire que la première colonne et l'index des colonne
# Si on ne le met pas Pandas va ajouter un index au dataframe (= valeur incrementiel)
reviews = pd.read_csv("dataset/ign.csv")

# %% [markdown]
# ## AFFICHER LES INFORMATIONS

# %%
# Afficher les premières lignes du dataset (par défaut les 5 premières)
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
# Afficher les dernières lignes du dataset (par défaut les 5 dernières)
reviews.tail()
# Out:
#        Unnamed: 0 score_phrase                                    title  \
# 18620       18620         Good                Tokyo Mirage Sessions #FE
# 18621       18621      Amazing        LEGO Star Wars: The Force Awakens
# 18622       18622     Mediocre  Star Ocean: Integrity and Faithlessness
# 18623       18623  Masterpiece                                   Inside
# 18624       18624  Masterpiece                                   Inside
#
#                                                      url       platform  \
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...          Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...  PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681  PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435       Xbox One
# 18624                 /games/inside-playdead/pc-20055740             PC
#
#        score              genre editors_choice  release_year  release_month  \
# ...

# %%
# Afficher le nombre de colonnes et le nombre de lignes
reviews.shape
# Out:
# (18625, 11)

# %% [markdown]
# ## INDEXING DATAFRAME

# %% [markdown]
# ### INDEXING PAR POSITION

# %%
# Afficher les (5) premières lignes du dataset
# 0:5 => correspond aux lignes de 0 à 5 (exclue)
#  :  => correspond à toutes les colonnes
reviews.iloc[0:5,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
# Remplacer le DataFrame "reviews" avec toutes les lignes et à partir de la colonne 1 du DataFrame "reviews"
reviews = reviews.iloc[:,1:]

# %% [markdown]
# ### INDEXING PAR LABEL

# %%
# Afficher les (5) premières lignes du dataset
reviews.loc[0:5,:]
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
# 5         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# ...

# %%
# Les index ne correspondent pas toujours aux positions.
# Exemple en créant un nouveau DataFrame dans lequel les positions et labels ne sont pas les mêmes
# Récupérer les lignes 10 à 20 de "reviews" et assignez le résultat à "some_reviews" 
some_reviews = reviews.iloc[10:20,] 

# Affiche les 5 premières lignes de "some_reviews"
some_reviews.head()
# Out:
#    score_phrase                    title  \
# 10         Good  Tekken Tag Tournament 2
# 11         Good  Tekken Tag Tournament 2
# 12         Good               Wild Blood
# 13      Amazing        Mark of the Ninja
# 14      Amazing        Mark of the Ninja
#
#                                                 url       platform  score  \
# 10        /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11   /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                  /games/wild-blood/iphone-139363         iPhone    7.0
# 13  /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14        /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
#
#                 genre editors_choice  release_year  release_month  release_day
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# ...

# %%
# Tenter d'afficher les lignes 9 à 20
# Cela va retourner une erreur
some_reviews.loc[9:21,:]
# Out:
#    score_phrase                            title  \
# 10         Good          Tekken Tag Tournament 2
# 11         Good          Tekken Tag Tournament 2
# 12         Good                       Wild Blood
# 13      Amazing                Mark of the Ninja
# 14      Amazing                Mark of the Ninja
# 15         Okay  Home: A Unique Horror Adventure
# 16         Okay  Home: A Unique Horror Adventure
# 17        Great              Avengers Initiative
# 18     Mediocre             Way of the Samurai 4
# 19         Good      JoJo's Bizarre Adventure HD
#
#                                                   url       platform  score  \
# 10          /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                    /games/wild-blood/iphone-139363         iPhone    7.0
# 13    /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# ...

# %%
# Afficher des colonnes spécifiques ("score") par labels plutôt que par position.
reviews.loc[:5,"score"]
# Out:
# 0    9.0
# 1    9.0
# 2    8.5
# 3    8.5
# 4    8.5
# 5    7.0
# Name: score, dtype: float64

# %%
# Afficher des colonnes spécifiques ("score" et "version_année") par labels.
reviews.loc [: 5, ["score", "release_year"]]
# Out:
#    score  release_year
# 0    9.0          2012
# 1    9.0          2012
# 2    8.5          2012
# 3    8.5          2012
# 4    8.5          2012
# 5    7.0          2012

# %% [markdown]
# ## PANDAS SERIES OBJECTS

# %%
# Afficher une colonne spécifique ("score")
reviews["score"]
# Out:
# 0         9.0
# 1         9.0
# 2         8.5
# 3         8.5
# 4         8.5
# 5         7.0
# 6         3.0
# 7         9.0
# 8         3.0
# 9         7.0
# 10        7.5
# 11        7.5
# 12        7.0
# 13        9.0
# 14        9.0
# 15        6.5
# 16        6.5
# 17        8.0
# 18        5.5
# 19        7.0
# 20        7.0
# 21        7.5
# 22        7.5
# 23        7.5
# 24        9.0
# 25        7.0
# 26        9.0
# 27        7.5
# 28        8.0
# 29        6.5
#          ...
# 18595     4.4
# 18596     6.5
# 18597     4.9
# 18598     6.8
# 18599     7.0
# 18600     7.4
# 18601     7.4
# 18602     7.4
# 18603     7.8
# 18604     8.6
# 18605     6.0
# 18606     6.4
# 18607     7.0
# 18608     5.4
# 18609     8.0
# 18610     6.0
# 18611     5.8
# 18612     7.8
# 18613     8.0
# 18614     9.2
# 18615     9.2
# 18616     7.5
# 18617     8.4
# 18618     9.1
# 18619     7.9
# 18620     7.6
# 18621     9.0
# 18622     5.8
# 18623    10.0
# 18624    10.0
# ...

# %%
# Afficher des listes de plusieurs colonnes
reviews[["score", "release_year"]]
# Out:
#        score  release_year
# 0        9.0          2012
# 1        9.0          2012
# 2        8.5          2012
# 3        8.5          2012
# 4        8.5          2012
# 5        7.0          2012
# 6        3.0          2012
# 7        9.0          2012
# 8        3.0          2012
# 9        7.0          2012
# 10       7.5          2012
# 11       7.5          2012
# 12       7.0          2012
# 13       9.0          2012
# 14       9.0          2012
# 15       6.5          2012
# 16       6.5          2012
# 17       8.0          2012
# 18       5.5          2012
# 19       7.0          2012
# 20       7.0          2012
# 21       7.5          2012
# 22       7.5          2012
# 23       7.5          2012
# 24       9.0          2012
# 25       7.0          2012
# 26       9.0          2012
# 27       7.5          2012
# 28       8.0          2012
# 29       6.5          2012
# ...      ...           ...
# 18595    4.4          2016
# 18596    6.5          2016
# ...

# %%
# Afficher le type d'objet "reviews["score"]"
# (pour vérifier que c'est bien une série)
type (reviews["score"])
# Out:
# pandas.core.series.Series

# %%
# Afficher le type d'objet "reviews["title"]"
# (pour vérifier que c'est bien une série)
type (reviews["title"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## PANDAS DATAFRAME METHODS

# %% [markdown]
# ### MOYENNES

# %%
# Afficher la moyenne de la colonne "score" de la serie "reviews["score"]"
reviews["score"].mean()
# Out:
# 6.950459060402666

# %%
# Afficher la moyenne de chaque colonne du DataFrame "reviews"
reviews.mean()
# Out:
# score               6.950459
# release_year     2006.515329
# release_month       7.138470
# release_day        15.603866
# dtype: float64

# %%
# Afficher la moyenne de chaque lignes du DataFrame "reviews"
reviews.mean(axis=1)
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
# 5        509.750
# 6        508.750
# 7        510.250
# 8        508.750
# 9        509.750
# 10       509.875
# 11       509.875
# 12       509.500
# 13       509.250
# 14       509.250
# 15       508.375
# 16       508.375
# 17       508.500
# 18       507.375
# 19       507.750
# 20       507.750
# 21       514.625
# 22       514.625
# 23       514.625
# 24       515.000
# 25       514.250
# 26       514.750
# 27       514.125
# 28       514.250
# 29       513.625
#           ...
# 18595    510.850
# 18596    510.875
# 18597    510.225
# 18598    510.700
# 18599    510.750
# 18600    512.600
# 18601    512.600
# 18602    512.600
# 18603    512.450
# 18604    512.400
# 18605    511.500
# 18606    508.600
# 18607    510.750
# 18608    510.350
# 18609    510.750
# 18610    510.250
# 18611    508.700
# 18612    509.200
# 18613    508.000
# 18614    515.050
# 18615    515.050
# ...

# %%
# Afficher la correlation entre les différentes colonnes du DataFrame "reviews"
reviews.corr()
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062716       0.007632     0.020079
# release_year   0.062716      1.000000      -0.115515     0.016867
# release_month  0.007632     -0.115515       1.000000    -0.067964
# release_day    0.020079      0.016867      -0.067964     1.000000

# %% [markdown]
# ## INDEXATION BOOLÉENNE DANS PANDAS

# %%
# Créer un DataFrame "score_filter" et y enregistrer les valeurs booléennes de "reviews["score"]" > 7
score_filter = reviews["score"] > 7 

# Afficher la Serie "score_filter"
score_filter
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
# 6        False
# 7         True
# 8        False
# 9        False
# 10        True
# 11        True
# 12       False
# 13        True
# 14        True
# 15       False
# 16       False
# 17        True
# 18       False
# 19       False
# 20       False
# 21        True
# 22        True
# 23        True
# 24        True
# 25       False
# 26        True
# 27        True
# 28        True
# 29       False
#          ...
# 18595    False
# 18596    False
# 18597    False
# 18598    False
# 18599    False
# 18600     True
# 18601     True
# 18602     True
# 18603     True
# 18604     True
# 18605    False
# 18606    False
# 18607    False
# 18608    False
# 18609     True
# 18610    False
# 18611    False
# 18612     True
# 18613     True
# 18614     True
# 18615     True
# 18616     True
# 18617     True
# 18618     True
# 18619     True
# 18620     True
# 18621     True
# ...

# %%
# Créer un DataFrame "filtered_reviews" et y insérer la Serie "score_filter"
filtered_reviews = reviews[score_filter]

# Afficher les (5) premières lignes du DataFrame "filtered_reviews"
filtered_reviews.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# ...

# %%
# Créer un DataFrame "xbox_one_filter" 
# et y enregistrer les valeurs booléennes de compâraison
# (reviews["score"]> 7) & (reviews["platform"] == "Xbox One")
xbox_one_filter = (reviews["score"]> 7) & (reviews["platform"] == "Xbox One")

# Créer un DataFrame "filter_reviews" et y insérer la Serie "xbox_one_filter"
filter_reviews = reviews[xbox_one_filter]

# Afficher les (5) premières lignes du DataFrame
filter_reviews.head()
# Out:
#       score_phrase                     title  \
# 17137      Amazing                 Gone Home
# 17197      Amazing            Rayman Legends
# 17295      Amazing  LEGO Marvel Super Heroes
# 17313        Great             Dead Rising 3
# 17317        Great           Killer Instinct
#
#                                                      url  platform  score  \
# 17137                 /games/gone-home/xbox-one-20014361  Xbox One    9.5
# 17197            /games/rayman-legends/xbox-one-20008449  Xbox One    9.5
# 17295  /games/lego-marvel-super-heroes/xbox-one-20000826  Xbox One    9.0
# 17313               /games/dead-rising-3/xbox-one-124306  Xbox One    8.3
# 17317      /games/killer-instinct-2013/xbox-one-20000538  Xbox One    8.4
#
#             genre editors_choice  release_year  release_month  release_day
# 17137  Simulation              Y          2013              8           15
# 17197  Platformer              Y          2013              8           26
# ...

# %%
# Fonction spéciale de Jupyter pour afficher les plots sur Jupyter Notebook
# %matplotlib inline

# Tracer la Serie reviews["score"] filtrée par reviews["platform"] == "Xbox One"
# Traçage de type "hist"
reviews[reviews["platform"] == "Xbox One"]["score"].plot(kind="hist")

# %%
# Tracer la Serie reviews["score"] filtrée par reviews["platform"] == "PlayStation 4"
# Traçage de type "hist"
reviews[reviews["platform"] == "PlayStation 4"]["score"].plot(kind="hist")

# %% [markdown]
# Il ressort de notre histogramme que la PlayStation 4 contient beaucoup plus de jeux très appréciés que la Xbox One.

# %%
filtered_reviews["score"].hist()

# %% [markdown]
# ## ========= PART 2 =========

# %% [markdown]
# ## IMPORTER LES LIBRAIRIES

# %%
# Importer la bibliothèque de pandas. 
import pandas as pd

# %% [markdown]
# ## IMPORTER LES DONNÉES

# %%
# Lire thanksgiving-2015-poll-data.csv dans un DataFrame que nous appelons "data".
data = pd.read_csv("dataset/thanksgiving-2015-poll-data.csv", encoding="UTF-8")

# %% [markdown]
# ## AFFICHER LES INFORMATIONS

# %%
# pandas.DataFrame.head - affiche les N premières lignes d’un DataFrame. Par défaut 5. 
data.head()
# pandas.DataFrame.tail - affiche les N dernières lignes d’un DataFrame. Par défaut 5.
data.tail()
# Out:
#       RespondentID Do you celebrate Thanksgiving?  \
# 1053    4335944082                            Yes
# 1054    4335943173                            Yes
# 1055    4335943060                            Yes
# 1056    4335934708                            Yes
# 1057    4335894916                            Yes
#
#      What is typically the main dish at your Thanksgiving dinner?  \
# 1053                                             Turkey
# 1054                                             Turkey
# 1055                             Other (please specify)
# 1056                                             Turkey
# 1057                                             Turkey
#
#      What is typically the main dish at your Thanksgiving dinner? - Other (please specify)  \
# 1053                                                NaN
# 1054                                                NaN
# 1055                                               Duck
# ...

# %%
# Afficher les valeurs uniques trouvées dans la colonne "Do you celebrate Thanksgiving?"
data["Do you celebrate Thanksgiving?"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
# Afficher les (50 premiers) noms des colonnes du DataFrame "data"
data.columns[50:]
# Out:
# Index(['Which of these desserts do you typically have at Thanksgiving dinner? Please select all that apply.   - Other (please specify).1',
#        'Do you typically pray before or after the Thanksgiving meal?',
#        'How far will you travel for Thanksgiving?',
#        'Will you watch any of the following programs on Thanksgiving? Please select all that apply. - Macy's Parade',
#        'What's the age cutoff at your "kids' table" at Thanksgiving?',
#        'Have you ever tried to meet up with hometown friends on Thanksgiving night?',
#        'Have you ever attended a "Friendsgiving?"',
#        'Will you shop any Black Friday sales on Thanksgiving Day?',
#        'Do you work in retail?',
#        'Will you employer make you work on Black Friday?',
#        'How would you describe where you live?', 'Age', 'What is your gender?',
#        'How much total combined money did all members of your HOUSEHOLD earn last year?',
#        'US Region'],
#       dtype='object')
